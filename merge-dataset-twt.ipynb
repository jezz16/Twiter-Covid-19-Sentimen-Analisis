# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df_twt1 = pd.read_csv('/kaggle/input/datasettwtcovidsby/covid358.csv', delimiter=";")
df_twt2 = pd.read_csv('/kaggle/input/datasettwtcovidsby/covid788.csv', delimiter=";")
df_twt3 = pd.read_csv('/kaggle/input/datasettwtcovidsby/covid19SBY(244).csv', delimiter=";")
df_twt4 = pd.read_csv('/kaggle/input/datasettwtcovidsby/covid19SBY(496).csv', delimiter=";")
df_twt5 = pd.read_csv('/kaggle/input/datasettwtcovidsby/covidSBY.old.csv', delimiter=";")

# %%
display(df_twt1)
# Out:
#                          created_at               id_str  \
# 0    Tue Dec 27 08:48:03 +0000 2022  1607659561867169793
# 1    Sun Dec 11 00:32:28 +0000 2022  1601736641424797696
# 2    Tue Dec 06 08:45:24 +0000 2022  1600048749576916994
# 3    Tue Dec 06 00:00:01 +0000 2022  1599916533827837952
# 4    Mon Nov 28 05:38:32 +0000 2022  1597102620891525120
# ..                              ...                  ...
# 353  Wed Dec 29 03:21:25 +0000 2021  1476030569511194627
# 354  Wed Dec 29 02:51:21 +0000 2021  1476023000411475970
# 355  Wed Dec 29 02:22:32 +0000 2021  1476015748212412418
# 356  Tue Dec 28 12:35:14 +0000 2021  1475807551157460994
# 357  Sat Dec 25 21:02:57 +0000 2021  1474848158672998400
#
#                                              full_text  quote_count  \
# 0    Kaleidoskop 2022: Gebrakan Padat Karya dan Des...            0
# 1    #Repost @djpl_ksutgperak  Halo #Kawanlaut, Pel...            0
# 2    #5 Kabupaten/Kota dengan Kasus Covid-19 Tertin...            0
# ...

# %%
df_twt1.columns
# Out:
# Index(['created_at', 'id_str', 'full_text', 'quote_count', 'reply_count',
#        'retweet_count', 'favorite_count', 'lang', 'user_id_str',
#        'conversation_id_str', 'username', 'tweet_url'],
#       dtype='object')

# %%
# df_twt1
df_twt1 = df_twt1[['full_text']]

# df_twt2
df_twt2 = df_twt2[['full_text']]

# df_twt3
df_twt3 = df_twt3[['full_text']]

# df_twt4
df_twt4 = df_twt4[['full_text']]

# df_twt5
df_twt5 = df_twt5[['full_text']]

# %%
display(df_twt2)
# Out:
#                                              full_text
# 0    Jangan lewatkan Pameran Arsip Pandemi Covid-19...
# 1    PPKM Dicabut, Satgas COVID-19 Surabaya Tetap B...
# 2    Surabaya Pertahankan Satgas Covid-19, Tunggu A...
# 3    #BeritaJatim  Jadwal dan Lokasi Vaksin Covid-1...
# 4    Jadwal dan Lokasi Vaksin Covid-19 Surabaya Har...
# ..                                                 ...
# 783  INFO VAKSINASI COVID-19 MODERNA DOSIS 1, 2 &am...
# 784  Rapat Verifikasi Dukungan Atas Capaian DLI (Di...
# 785  Jemaah haji kloter 1 asal Kabupaten Tuban, Jaw...
# 786  Covid-19 Naik Lagi, Wali Kota Eri Terbitkan SE...
# 787  Booster Jadi Syarat Masuk Ruang Publik, Khofif...
#
# [788 rows x 1 columns]

# %%
# Gabungkan df_twt1 hingga df_twt5
merged_dataframe = pd.concat([df_twt1, df_twt2, df_twt3, df_twt4, df_twt5], ignore_index=True)

# Cetak hasil gabungan
print(merged_dataframe)
# Out:
#                                               full_text
# 0     Kaleidoskop 2022: Gebrakan Padat Karya dan Des...
# 1     #Repost @djpl_ksutgperak  Halo #Kawanlaut, Pel...
# 2     #5 Kabupaten/Kota dengan Kasus Covid-19 Tertin...
# 3     Angka kasus COVID-19 di Kabupaten Malang kemba...
# 4     Pemerintah Kota Surabaya terus berupaya mengge...
# ...                                                 ...
# 2119  Semakin Meningkat di Jatim, Ketahui Gejala Cov...
# 2120  Organisasi Kesehatan Dunia (WHO) secara resmi ...
# 2121  Jadwal dan Lokasi Vaksin Covid-19 Surabaya Har...
# 2122  #BeritaJatim  Jadwal dan Lokasi Vaksin Covid-1...
# 2123  @e100ss Ketika WHO sudah bilang BEBAS COVID, w...
#
# [2124 rows x 1 columns]

# %%
merged_dataframe.to_csv('merged_dataset.csv', index=False)
